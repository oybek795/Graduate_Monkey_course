# %%
N = 5
menMeans = (20, 35, 30, 35, -27)
womenMeans = (25, 32, 34, 20, -25)
menStd = (2, 3, 4, 1, 2)
womenStd = (3, 5, 2, 3, 3)
ind = np.arange(N)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8dba3d5ed5b8> in <module>
#       4 menStd = (2, 3, 4, 1, 2)
#       5 womenStd = (3, 5, 2, 3, 3)
# ----> 6 ind = np.arange(N)    # the x locations for the groups
#       7 width = 0.35       # the width of the bars: can also be len(x) sequence
#
# NameError: name 'np' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np
N = 5
menMeans = (20, 35, 30, 35, -27)
womenMeans = (25, 32, 34, 20, -25)
menStd = (2, 3, 4, 1, 2)
womenStd = (3, 5, 2, 3, 3)
ind = np.arange(N)    
width = 0.35       
fig, ax = plt.subplots()
p1 = ax.bar(ind, menMeans, width, yerr=menStd, label='Teachers')
p2 = ax.bar(ind, womenMeans, width,
            bottom=menMeans, yerr=womenStd, label='Students')
ax.axhline(0, color='grey', linewidth=0.8)
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(ind)
ax.set_xticklabels(('G1', 'G2', 'G3', 'G4', 'G5'))
ax.legend()
ax.bar_label(p1, label_type='center')
ax.bar_label(p2, label_type='center')
ax.bar_label(p2)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-47563cabe1fe> in <module>
#      18 ax.set_xticklabels(('G1', 'G2', 'G3', 'G4', 'G5'))
#      19 ax.legend()
# ---> 20 ax.bar_label(p1, label_type='center')
#      21 ax.bar_label(p2, label_type='center')
#      22 ax.bar_label(p2)
#
# AttributeError: 'AxesSubplot' object has no attribute 'bar_label'

# %%
import pandas as pd
from matplotlib import pyplot as plt
x = [1, 2, 3]
y = [1, 4, 9]
z = [10, 5, 0]
plt.plot(x, y)
plt.plot(x, z)
plt.title("test plot")
plt.xlabel("x")
plt.ylabel("y and z")
plt.legend(["Teachers", "students"])
plt.show()
