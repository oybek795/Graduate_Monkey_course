# %%
enter = input("Enter your name:")

if enter == "Admin":
    print ("Hola Qobiljon, do you feel yourself better?")
    temp = input("what is your temp?")
    if temp > "36.6":
        print ("Please stay at home!")
    else:
        print ("You are good now")
else:
    print ("Hello, stranger")
# Out:
# Enter your name: Admin
# Hola Qobiljon, do you feel yourself better?
# what is your temp? 38
# Please stay at home!
